# %% [markdown]
# # Historical Trends in Sector Stock Holding

# %%
from bs4 import BeautifulSoup # importing the BeautifulSoup library
import requests # importing requests library

# %%
url = "https://www.etmoney.com/mutual-funds/quant-mid-cap-fund-direct-growth/portfolio-details/16934"# Quant mid Cap fund url from et money website.

page = requests.get(url) # to perform an HTTP GET request to the URL.

soup = BeautifulSoup(page.text,'html') # default HTML parser provided by BeautifulSoup to parse the HTML content.

# %%
soup
# Out:
# <!DOCTYPE html>
# ...

# %% [markdown]
# ## Finding and extracting the required Table from HTML text format

# %%
tables = soup.find_all('table')[1]

# %%
tables
# Out:
# <table class="table"><thead><tr><th>Sector Allocation</th><th class="time-string" data-key="0">Nov 23</th><th class="time-string" data-key="1">Oct 23</th><th class="time-string" data-key="2">Sep 23</th><th class="time-string" data-key="3">Aug 23</th><th class="time-string" data-key="4">Jul 23</th><th class="time-string" data-key="5">Jun 23</th><th class="time-string" data-key="6">May 23</th><th class="time-string" data-key="7">Apr 23</th><th class="time-string" data-key="8">Mar 23</th><th class="time-string" data-key="9">Feb 23</th><th class="time-string" data-key="10">Jan 23</th><th class="time-string" data-key="11">Dec 22</th><th class="time-string hide" data-key="12">Nov 22</th><th class="time-string hide" data-key="13">Oct 22</th><th class="time-string hide" data-key="14">Sep 22</th><th class="time-string hide" data-key="15">Aug 22</th><th class="time-string hide" data-key="16">Jul 22</th><th class="time-string hide" data-key="17">Jun 22</th><th class="time-string hide" data-key=
# ...

# %% [markdown]
# ## Extracting the columns data from above HTML text format by using 'find_all' method.

# %%
seat_allocation = tables.find_all('th')

# %%
seat_allocation
# Out:
# [<th>Sector Allocation</th>,
#  <th class="time-string" data-key="0">Nov 23</th>,
#  <th class="time-string" data-key="1">Oct 23</th>,
#  <th class="time-string" data-key="2">Sep 23</th>,
#  <th class="time-string" data-key="3">Aug 23</th>,
#  <th class="time-string" data-key="4">Jul 23</th>,
#  <th class="time-string" data-key="5">Jun 23</th>,
#  <th class="time-string" data-key="6">May 23</th>,
#  <th class="time-string" data-key="7">Apr 23</th>,
#  <th class="time-string" data-key="8">Mar 23</th>,
#  <th class="time-string" data-key="9">Feb 23</th>,
#  <th class="time-string" data-key="10">Jan 23</th>,
#  <th class="time-string" data-key="11">Dec 22</th>,
#  <th class="time-string hide" data-key="12">Nov 22</th>,
#  <th class="time-string hide" data-key="13">Oct 22</th>,
#  <th class="time-string hide" data-key="14">Sep 22</th>,
#  <th class="time-string hide" data-key="15">Aug 22</th>,
#  <th class="time-string hide" data-key="16">Jul 22</th>,
# ...

# %%
# creating a list of value included in columns.
seat_allocation_row = [titles.text.strip() for titles in seat_allocation]

# %%
seat_allocation_row
# Out:
# ['Sector Allocation',
#  'Nov 23',
#  'Oct 23',
#  'Sep 23',
#  'Aug 23',
#  'Jul 23',
#  'Jun 23',
#  'May 23',
#  'Apr 23',
#  'Mar 23',
#  'Feb 23',
#  'Jan 23',
#  'Dec 22',
#  'Nov 22',
#  'Oct 22',
#  'Sep 22',
#  'Aug 22',
#  'Jul 22',
#  'Jun 22',
#  'May 22',
#  'Apr 22',
#  'Mar 22',
#  'Feb 22',
#  'Jan 22',
#  'Dec 21',
#  'Nov 21',
#  '']

# %%
import pandas as pd

df = pd.DataFrame(columns=seat_allocation_row)

# %%
df
# Out:
# Empty DataFrame
# Columns: [Sector Allocation, Nov 23, Oct 23, Sep 23, Aug 23, Jul 23, Jun 23, May 23, Apr 23, Mar 23, Feb 23, Jan 23, Dec 22, Nov 22, Oct 22, Sep 22, Aug 22, Jul 22, Jun 22, May 22, Apr 22, Mar 22, Feb 22, Jan 22, Dec 21, Nov 21, ]
# Index: []
#
# [0 rows x 27 columns]

# %%
column_name = df.to_excel(r"T:\Data Field\Excel\Quant column name.xlsx")

# %%
column_name

# %%
column_data = tables.find_all("tr")

# %% [markdown]
# ## Extracting rows data from HTML text

# %%
for row in column_data[1:]:
    row_data = row.find_all("td")
    individual_row_data = [data.text.strip() for data in row_data]
    print(individual_row_data)
    pd.DataFrame(individual_row_data)
# Out:
# ['Healthcare', '20.319999999999997 %', '7.683132E9', '13.88 %', '4.536892E9', '8.809999999999999 %', '2.761209E9', '7.77 %', '2.163372E9', '5.18 %', '1.309852E9', '9.110000000000001 %', '1.991985E9', '14.169999999999998 %', '2.796567E9', '13.15 %', '2.461785E9', '10.95 %', '1.822259E9', '10.92 %', '1.694098E9', '3.4 %', '5.06581E8', '5.550000000000001 %', '7.37959E8', '5.97 %', '7.60709E8', '5.0 %', '4.81588E8', '4.790000000000001 %', '4.1281E8', '3.02 %', '2.14222E8', '1.36 %', '8.4608E7', '5.38 %', '2.87423E8', '5.95 %', '3.03691E8', '7.449999999999999 %', '3.42095E8', '6.91 %', '2.49723E8', '5.64 %', '1.59732E8', '7.09 %', '1.9111319E8', '9.08 %', '2.2502719E8', '9.67 %', '2.14727273E8', '10.03', '']
# ...

# %%
data = [
    ['Healthcare', '20.319999999999997 %', '7.683132E9', '13.88 %', '4.536892E9', '8.809999999999999 %', '2.761209E9', '7.77 %', '2.163372E9', '5.18 %', '1.309852E9', '9.110000000000001 %', '1.991985E9', '14.169999999999998 %', '2.796567E9', '13.15 %', '2.461785E9', '10.95 %', '1.822259E9', '10.92 %', '1.694098E9', '3.4 %', '5.06581E8', '5.550000000000001 %', '7.37959E8', '5.97 %', '7.60709E8', '5.0 %', '4.81588E8', '4.790000000000001 %', '4.1281E8', '3.02 %', '2.14222E8', '1.36 %', '8.4608E7', '5.38 %', '2.87423E8', '5.95 %', '3.03691E8', '7.449999999999999 %', '3.42095E8', '6.91 %', '2.49723E8', '5.64 %', '1.59732E8', '7.09 %', '1.9111319E8', '9.08 %', '2.2502719E8', '9.67 %', '2.14727273E8', '10.03', ''],
['Energy', '17.5 %', '6.614948E9', '21.16 %', '6.911432E9', '8.440000000000001 %', '2.647211E9', '8.99 %', '2.507801E9', '9.23 %', '2.33722E9', '11.879999999999999 %', '2.600972E9', '11.54 %', '2.276361E9', '11.469999999999999 %', '2.147478E9', '8.49 %', '1.414529E9', '2.29 %', '3.5535E8', '2.54 %', '3.7872E8', '2.84 %', '3.77802E8', '0 %', '0', '3.25 %', '3.13311E8', '4.51 %', '3.88833E8', '4.19 %', '2.9684E8', '4.14 %', '2.5696E8', '5.92 %', '3.16809E8', '7.28 %', '3.71428E8', '6.02 %', '2.76878E8', '3.37 %', '1.21647E8', '1.97 %', '5.5763E7', '0 %', '0', '0 %', '0', '1.64 %', '3.644181E7', '3.77', ''],
]

# %%
df1 = pd.DataFrame(data)

# %% [markdown]
# ### Creating a dataframe of row data by using pandas module

# %%
df1
# Out:
#                  0                     1           2                     3   \
# 0        Healthcare  20.319999999999997 %  7.683132E9               13.88 %
# 1            Energy                17.5 %  6.614948E9               21.16 %
# 2         Financial                17.1 %  6.466757E9  13.540000000000001 %
# 3     Capital Goods                9.51 %  3.597327E9                9.66 %
# 4         Chemicals                7.88 %  2.978948E9                9.24 %
# 5   Metals & Mining                6.53 %  2.465706E9                5.98 %
# 6          Services                6.43 %  2.432915E9                6.34 %
# 7        Automobile                6.21 %  2.347998E9   9.030000000000001 %
# 8     Communication                6.02 %  2.275861E9   5.859999999999999 %
# 9        Technology  1.6600000000000001 %   6.25591E8                0.99 %
# 10        Materials                1.54 %   5.82171E8                3.76 %
#
# ...

# %% [markdown]
# ## Data cleaning

# %%
columns_to_remove = df1[range(2,53,2)]

# %% [markdown]
# ### Remove the exponential value from the dataset.

# %%
clean_data = df1.drop(columns=columns_to_remove,axis=1)

# %%
clean_data
# Out:
#                  0                     1                     3   \
# 0        Healthcare  20.319999999999997 %               13.88 %
# 1            Energy                17.5 %               21.16 %
# 2         Financial                17.1 %  13.540000000000001 %
# 3     Capital Goods                9.51 %                9.66 %
# 4         Chemicals                7.88 %                9.24 %
# 5   Metals & Mining                6.53 %                5.98 %
# 6          Services                6.43 %                6.34 %
# 7        Automobile                6.21 %   9.030000000000001 %
# 8     Communication                6.02 %   5.859999999999999 %
# 9        Technology  1.6600000000000001 %                0.99 %
# 10        Materials                1.54 %                3.76 %
#
#                      5                     7                      9   \
# 0   8.809999999999999 %                7.77 %                 5.18 %
# ...

# %% [markdown]
# ### Add the column values in rows dataframe(clean_data).

# %%
column_name = ['Sector Allocation','Nov 23','Oct 23','Sep 23','Aug 23','Jul 23','Jun 23','May 23','Apr 23','Mar 23','Feb 23','Jan 23','Dec 22','Nov 22','Oct 22','Sep 22','Aug 22','Jul 22','Jun 22','May 22','Apr 22','Mar 22','Feb 22','Jan 22','Dec 21','Nov 21','Dec 21'
]

# %%
clean_data.columns = column_name

# %%
clean_data
# Out:
#    Sector Allocation                Nov 23                Oct 23  \
# 0         Healthcare  20.319999999999997 %               13.88 %
# 1             Energy                17.5 %               21.16 %
# 2          Financial                17.1 %  13.540000000000001 %
# 3      Capital Goods                9.51 %                9.66 %
# 4          Chemicals                7.88 %                9.24 %
# 5    Metals & Mining                6.53 %                5.98 %
# 6           Services                6.43 %                6.34 %
# 7         Automobile                6.21 %   9.030000000000001 %
# 8      Communication                6.02 %   5.859999999999999 %
# 9         Technology  1.6600000000000001 %                0.99 %
# 10         Materials                1.54 %                3.76 %
#
#                  Sep 23                Aug 23                 Jul 23  \
# 0   8.809999999999999 %                7.77 %                 5.18 %
# ...

# %%
#Converting the datframe into .csv file.
required_data = clean_data.to_csv(r"T:\Data Field\Data scrapping\Quant Mid Cap Fund.csv",index=False)

# %%
required_data
